# %% [markdown]
# <a href="https://colab.research.google.com/github/VayoniGamage/VayoniGamage/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#create series and data frames as pandas

from google.colab import data_table
data_table.enable_dataframe_formatter()

data_series = pd.Series([30,400,50,60])
print("Series")
print(data_series)

#create a dataframe
data_dict = {'Name':['Kamal','Nimal'],
             'Age' :[34,12],
            }
data_df = pd.DataFrame(data_dict)
print("\nDataFrame")
print(data_df)

#Create a series with index values
s2 = pd.Series ( [1,2,3,4], index=['a','b','c','d'])
print(s2)

#create a DataFrame
df1 = pd.DataFrame(np.random.randn(4,3))
df1
print(df1)

data_df
# Out:
# Series
# 0     30
# 1    400
# 2     50
# 3     60
# dtype: int64
#
# DataFrame
#     Name  Age
# 0  Kamal   34
# 1  Nimal   12
# a    1
# b    2
# c    3
# d    4
# dtype: int64
#           0         1         2
# 0  0.595131 -1.519127 -0.778013
# 1 -0.906257  0.261079  1.008322
# 2  0.382399  0.191893 -0.571771
# 3  1.232539 -0.245734 -0.315823
#     Name  Age
# 0  Kamal   34
# 1  Nimal   12
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...
